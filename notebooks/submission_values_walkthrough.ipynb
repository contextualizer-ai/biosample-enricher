# %%
from biosample_enricher.submission_values import get_submission_values

# %%
result = get_submission_values(
    lat=37.7749,  # San Francisco
    lon=-122.4194,
    slots=["annual_precpt", "annual_temp"],
)
# Out:
# Meteostat only provides 30-year climate normals for WMO standard periods. Requested 1995-2025 is invalid. Using 1991-2020 instead. Valid periods: 1961-1990, 1971-2000, 1981-2010, 1991-2020. See: https://dev.meteostat.net/python/normals.html
# NASA POWER only provides 2001-2020 climatologies. Requested 1995-2025 will be ignored.

# %%
result
# Out:
# {'values': {'annual_precpt': 519.315, 'annual_temp': 14.095416666666669},
#  'metadata': {'climate_normals': {'providers_used': ['meteostat',
#     'nasa_power'],
#    'consensus_strategy': 'consensus',
#    'requested_start_year': 1995,
#    'requested_end_year': 2025,
#    'provider_results': {'meteostat': {'annual_precpt': 453.0999999999999,
#      'annual_temp': 14.625,
#      'returned_start_year': 1991,
#      'returned_end_year': 2020,
#      'station_distance_km': 9.074100559394836},
#     'nasa_power': {'annual_precpt': 585.5300000000001,
#      'annual_temp': 13.565833333333336,
#      'returned_start_year': 2001,
#      'returned_end_year': 2020,
#      'station_distance_km': None}},
#    'failed_providers': {}}}}

# %% [markdown]
# Daily mean temperature celsius from wikipedia 14.3
# Daily mean precip milimeters from Wikipedia 581
